# %% [markdown]
# <h3>Exploratory Analysis<h3>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\_coding projects\ml projects\tiktok streamlit data science app\tiktokanalytics\lib\site-packages (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\_coding projects\ml projects\tiktok streamlit data science app\tiktokanalytics\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\_coding projects\ml projects\tiktok streamlit data science app\tiktokanalytics\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in d:\_coding projects\ml projects\tiktok streamlit data science app\tiktokanalytics\lib\site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in d:\_coding projects\ml projects\tiktok streamlit data science app\tiktokanalytics\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#Import pandas 
import pandas as pd

# %%
#Reading the json file we scraped
df = pd.read_json('export.json')

# %%
#View the first 5 row in the json file
df.head()
# Out:
#                     id                                               desc  \
# 0  6941410706021469184  #tpwk #harrystyles #foryou #grammys2021 #fyp @...
# 1  6855496386352286720  Uh bye🥺 #onedirection #1d #zaynmalik #harrysty...
# 2  7028574605161925632  No me roben mi show! 😂😑#harrystylesvids #harry...
# 3  6957502058173828096  :^) #greenscreenvideo #zodiactiktok #zodiacs #...
# 4  6833129327568096256  oh harry... #onedirection #harrystyles #thisis...
#
#    createTime                                              video  \
# 0  1616173125  {'id': '6941410706021469445', 'height': 960, '...
# 1  1596169641  {'id': '6855496386352286981', 'height': 1024, ...
# 2  1636467551  {'id': '7028574605161925894', 'height': 1024, ...
# 3  1619919686  {'id': '6957502058173828358', 'height': 1024, ...
# 4  1590961900  {'id': '6833129327568096517', 'height': 960, '...
#
#                                               author  \
# 0  {'id': '58387579993071616', 'uniqueId': 'blems...
# 1  {'id': '6771620976251749382', 'uniqueId': 'daj...
# 2  {'id': '127297643138965504', 'uniqueId': 'nico...
# 3  {'id': '6930680973231703045', 'uniqueId': 'zod...
# 4  {'id': '6816923689738617862', 'uniqueId': 'eve...
#
#                                                music  \
# 0  {'id': '6941410570830711558', 'title': 'sonido...
# 1  {'id': '6546179841098535936', 'title': 'well s...
# 2  {'id': '7028574406758746885', 'title': 'sonido...
# 3  {'id': '6955510506778020614', 'title': 'origin...
# 4  {'id': '6833129303358589702', 'title': 'origin...
#
#                                           challenges  \
# 0  [{'id': '1598907916025861', 'title': 'tpwk', '...
# 1  [{'id': '996', 'title': 'onedirection', 'desc'...
# 2  [{'id': '1649872828350470', 'title': 'harrysty...
# 3  [{'id': '79073378', 'title': 'greenscreenvideo...
# 4  [{'id': '996', 'title': 'onedirection', 'desc'...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 2100000, 'shareCount': 58100, 'c...  {'duetFromId': '0'}
# 1  {'diggCount': 1900000, 'shareCount': 35700, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 1800000, 'shareCount': 22400, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 1600000, 'shareCount': 15200, 'c...  {'duetFromId': '0'}
# 4  {'diggCount': 1500000, 'shareCount': 67700, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...                                        authorStats  \
# 0         False  ...  {'followingCount': 562, 'followerCount': 35000...
# 1         False  ...  {'followingCount': 1130, 'followerCount': 2990...
# 2         False  ...  {'followingCount': 1017, 'followerCount': 2679...
# 3         False  ...  {'followingCount': 580, 'followerCount': 30700...
# 4         False  ...  {'followingCount': 9, 'followerCount': 179800,...
#
#   privateItem  duetEnabled  stitchEnabled  shareEnabled  \
# 0       False         True           True          True
# 1       False         True           True          True
# 2       False        False          False          True
# 3       False        False          False          True
# 4       False         True           True          True
#
#                                       stickersOnItem   isAd  duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['Kunno dic...  False            0
# 1  [{'stickerType': 4, 'stickerText': ['Harry had...  False            0
# 2                                                NaN  False            0
# 3                                                NaN  False            0
# 4                                                NaN  False            0
#
#    stitchDisplay effectStickers
# 0              0            NaN
# 1              0            NaN
# 2              0            NaN
# 3              0            NaN
# 4              0            NaN
#
# [5 rows x 29 columns]

# %%
#Exporting to csv file
df.to_csv('tiktokdata_unrefined.csv')

# %% [markdown]
# # Create Helper Function to process Data

# %%
#Importjson library to load the json file
import json

# %%
#Load up data
with open('export.json' , 'r') as f:
    data = json.load(f)

# %%
#These are in nested format. So need to carry additional preprocesing
nested_values = ['video', 'author', 'music', 'stats', 'authorStats', 'challenges', 'duetInfo', 'textExtra', 'stickersOnItem']

#These are worthless data that we will skip
skip_values = ['challenges', 'duetInfo', 'textExtra', 'stickersOnItem']

# %%
#Create blank dictionary
flattened_data = {}

#Loop through each video
for idx,value in enumerate(data):                         #Adding a unique index to the data
    flattened_data[idx] = {}
    
    #loop through each property in each video
    for property_id, property_val in value.items():       
    #Checking if its nested data
        if property_id in nested_values: 
            #Checking if its a skip data
            if property_id in skip_values:
                pass           
            else:
                #Loop through each nested property
                for nested_idx, nested_val in property_val.items():
                    flattened_data[idx][property_id+'_'+nested_idx] = nested_val
        #If not a nested data add them to the flattened data dictionary
        else:
            flattened_data[idx][property_id] = property_val

# %%
flattened_data[0]
# Out:
# {'id': '6941410706021469445',
#  'desc': '#tpwk #harrystyles #foryou #grammys2021 #fyp @hshq',
#  'createTime': 1616173125,
#  'video_id': '6941410706021469445',
#  'video_height': 960,
#  'video_width': 540,
#  'video_duration': 9,
#  'video_ratio': '720p',
#  'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/603ed4ab236a41e99bcd9e1cfe911167_1616173127?x-expires=1645311600&x-signature=oBLv4pZbMFUcOtXS0tc81R5ptQU%3D',
#  'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/96e0ee41921b40e3b8f1b9caee79738c_1616173128?x-expires=1645311600&x-signature=qbZ%2FVo8lLvE%2FkYN9kmvO%2BQVu7oE%3D',
#  'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/5fdc8c8fb1d24799982c8ba7b6de7d82_1616173164?x-expires=1645311600&x-signature=YJFqEk%2BOhuBdcObYw1v69M94bT8%3D',
#  'video_playAddr': 'https://v16-webapp.tiktok.com/52d24ae5e2533afef896b45b7955c84d/6211783d/video/tos/useast2a/tos-useast2a-pve-0068/f5d6047d5e5c454cbdcf0c18a41db1b6/?a=1988&br=1108&bt=554&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-38onz7Thgry9DXq&l=2022021917073201024502005601ED7C55&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3k3dDt4OmZnNDMzZzczM0ApNWc0OjpmOjw5N2U2aGgzNGdsbHFvaW9vZF5gLS0xMTZzczY1MjIxM15eM19fYC1jMTU6Yw%3D%3D&vl=&vr=',
#  'video_downloadAddr': 'https://v16-webapp.tiktok.com/52d24ae5e2533afef896b45b7955c84d/6211783d/video/tos/useast2a/tos-useast2a-pve-0068/f5d6047d5e5c454cbdcf0c18a41db1b6/?a=1988&br=1108&bt=554&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-38onz7Thgry9DXq&l=2022021917073201024502005601ED7C55&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3k3dDt4OmZnNDMzZzczM0ApNWc0OjpmOjw5N2U2aGgzNGdsbHFvaW9vZF5gLS0xMTZzczY1MjIxM15eM19fYC1jMTU6Yw%3D%3D&vl=&vr=',
#  'video_shareCover': ['',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/96e0ee41921b40e3b8f1b9caee79738c_1616173128~tplv-tiktok-play.jpeg?x-expires=1645894800&x-signature=OxvJen2L6f04nRYW70eSgVoaccM%3D',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/96e0ee41921b40e3b8f1b9caee79738c_1616173128~tplv-tiktokx-share-play.jpeg?x-expires=1645894800&x-signature=EKjnPftnLH%2FDyq0L9%2BMxsVzhnDI%3D'],
#  'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/603ed4ab236a41e99bcd9e1cfe911167_1616173127?x-expires=1645311600&x-signature=oBLv4pZbMFUcOtXS0tc81R5ptQU%3D',
#  'video_bitrate': 567900,
#  'video_encodedType': 'normal',
#  'video_format': 'mp4',
#  'video_videoQuality': 'normal',
#  'video_encodeUserTag': '',
#  'video_codecType': 'h264',
#  'video_definition': '720p',
#  'author_id': '58387579993071616',
#  'author_uniqueId': 'blemstylinson',
#  'author_nickname': 'Bal',
#  'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_100x100.jpeg?x-expires=1645376400&x-signature=ws1BLB6qU%2BG%2BA4W%2BSYU6pneFa%2Fk%3D',
#  'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_720x720.jpeg?x-expires=1645376400&x-signature=%2FQegattK4y%2B1fsDO3SamF8RJHTM%3D',
#  'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_1080x1080.jpeg?x-expires=1645376400&x-signature=uISqKYtx6IAu0aoFLhR%2B7tv%2Bs74%3D',
#  'author_signature': '🏳️\u200d🌈\nShe/her\nBuzzing Larrie',
#  'author_verified': False,
#  'author_secUid': 'MS4wLjABAAAAiqaWEjZRAbZvtbxMNvRTV1wUaAWkMHw_oYKUvnI3UOgwW2SCNOjIz39d0URyOtJA',
#  'author_secret': False,
#  'author_ftc': False,
#  'author_relation': 0,
#  'author_openFavorite': False,
#  'author_commentSetting': 0,
#  'author_duetSetting': 3,
#  'author_stitchSetting': 3,
#  'author_privateAccount': False,
#  'author_isADVirtual': False,
#  'music_id': '6941410570830711558',
#  'music_title': 'sonido original',
#  'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6941410688699075334.mp3',
#  'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_100x100.jpeg?x-expires=1645376400&x-signature=ws1BLB6qU%2BG%2BA4W%2BSYU6pneFa%2Fk%3D',
#  'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_720x720.jpeg?x-expires=1645376400&x-signature=%2FQegattK4y%2B1fsDO3SamF8RJHTM%3D',
#  'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/6356a078b90089f666c333d08dea5a1b~c5_1080x1080.jpeg?x-expires=1645376400&x-signature=uISqKYtx6IAu0aoFLhR%2B7tv%2Bs74%3D',
#  'music_authorName': 'Bal',
#  'music_original': True,
#  'music_duration': 9,
#  'music_album': '',
#  'stats_diggCount': 2100000,
#  'stats_shareCount': 58100,
#  'stats_commentCount': 32800,
#  'stats_playCount': 10200000,
#  'originalItem': False,
#  'officalItem': False,
#  'secret': False,
#  'forFriend': False,
#  'digged': False,
#  'itemCommentStatus': 0,
#  'showNotPass': False,
#  'vl1': False,
#  'itemMute': False,
#  'authorStats_followingCount': 562,
#  'authorStats_followerCount': 35000,
#  'authorStats_heartCount': 2200000,
#  'authorStats_videoCount': 6,
#  'authorStats_diggCount': 86800,
#  'authorStats_heart': 2200000,
#  'privateItem': False,
#  'duetEnabled': True,
#  'stitchEnabled': True,
#  'shareEnabled': True,
#  'isAd': False,
#  'duetDisplay': 0,
#  'stitchDisplay': 0}

# %% [markdown]
# # Test out Output

# %%
df_test = pd.DataFrame.from_dict(flattened_data, orient='index')

# %%
df_test.head()
# Out:
#                     id                                               desc  \
# 0  6941410706021469445  #tpwk #harrystyles #foryou #grammys2021 #fyp @...
# 1  6855496386352286981  Uh bye🥺 #onedirection #1d #zaynmalik #harrysty...
# 2  7028574605161925894  No me roben mi show! 😂😑#harrystylesvids #harry...
# 3  6957502058173828358  :^) #greenscreenvideo #zodiactiktok #zodiacs #...
# 4  6833129327568096517  oh harry... #onedirection #harrystyles #thisis...
#
#    createTime             video_id  video_height  video_width  video_duration  \
# 0  1616173125  6941410706021469445           960          540               9
# 1  1596169641  6855496386352286981          1024          576              14
# 2  1636467551  7028574605161925894          1024          576              66
# 3  1619919686  6957502058173828358          1024          576              13
# 4  1590961900  6833129327568096517           960          540              50
#
#   video_ratio                                        video_cover  \
# 0        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                    video_originCover  ...  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...
#
#   authorStats_diggCount authorStats_heart privateItem duetEnabled  \
# 0                 86800           2200000       False        True
# 1                136000           4700000       False        True
# 2                 11100          28700000       False       False
# 3                  1306           1700000       False       False
# 4                   394          10100000       False        True
#
#   stitchEnabled  shareEnabled   isAd duetDisplay stitchDisplay effectStickers
# 0          True          True  False           0             0            NaN
# 1          True          True  False           0             0            NaN
# 2         False          True  False           0             0            NaN
# 3         False          True  False           0             0            NaN
# 4          True          True  False           0             0            NaN
#
# [5 rows x 77 columns]

# %%
#Exporting the much cleaner data to csv
df_test.to_csv('analytics.csv')
